# %%
import pandas as pd
import numpy as np
df = pd.read_csv("student_placement_prediction_dataset_2026.csv")

# %%
df
# Out:
#        student_id  age  gender  cgpa      branch college_tier  \
# 0               1   24    Male  7.53          IT       Tier 2
# 1               2   21    Male  7.92         CSE       Tier 2
# 2               3   22  Female  8.60         EEE       Tier 1
# 3               4   24    Male  6.68         CSE       Tier 1
# 4               5   20  Female  8.43          IT       Tier 3
# ...           ...  ...     ...   ...         ...          ...
# 99995       99996   21    Male  7.97  Mechanical       Tier 2
# 99996       99997   18  Female  7.79         CSE       Tier 1
# 99997       99998   20  Female  6.71          IT       Tier 2
# 99998       99999   19  Female  7.21         CSE       Tier 2
# 99999      100000   22  Female  8.58         ECE       Tier 3
#
#        internships_count  projects_count  certifications_count  \
# 0                      4               6                     1
# 1                      1               3                     6
# 2                      0               1                     1
# 3                      0               2                     2
# 4                      1               4                     3
# ...                  ...             ...                   ...
# 99995                  0               3                     5
# 99996                  1               1                     2
# 99997                  2               4                     4
# 99998                  2               3                     0
# 99999                  1               3                     2
#
#        coding_skill_score  ...  mock_interview_score  attendance_percentage  \
# 0               99.238568  ...             72.647009              77.463863
# 1               80.966123  ...             61.699110              88.887600
# 2               49.177184  ...             87.396911              74.153265
# 3               79.359084  ...             58.401069              87.635955
# 4               65.018573  ...             74.489201              79.120749
# ...                   ...  ...                   ...                    ...
# 99995           71.483407  ...             57.738311              75.471631
# 99996           78.960574  ...             80.076688              77.286948
# 99997           66.691775  ...             70.797752              93.115933
# 99998           67.214893  ...             68.182555              71.306355
# 99999           92.146277  ...             77.864288              89.919640
#
#        backlogs  extracurricular_score  leadership_score  \
# 0             2              63.382726         52.938240
# 1             1              73.694605         60.198856
# 2             0              63.329294         43.708803
# 3             1              47.636099         56.549154
# 4             1               0.000000         67.268893
# ...         ...                    ...               ...
# 99995         0              54.399022         66.446410
# 99996         1              33.692154         69.025632
# 99997         0              64.989215         32.733645
# 99998         1              72.478779         32.205517
# 99999         0              48.363818         21.166444
#
#        volunteer_experience  sleep_hours  study_hours_per_day  \
# 0                       Yes          6.7                  3.6
# 1                        No          4.4                  2.3
# 2                        No          8.8                  5.9
# 3                       Yes          8.1                  4.4
# 4                        No          8.7                  3.4
# ...                     ...          ...                  ...
# 99995                   Yes          8.0                  4.3
# 99996                   Yes          4.4                  3.1
# 99997                   Yes          7.6                  2.9
# 99998                    No          4.9                  2.8
# 99999                   Yes          6.5                  2.9
#
#        placement_status  salary_package_lpa
# 0            Not Placed                0.00
# 1            Not Placed                0.00
# 2                Placed               11.99
# 3            Not Placed                0.00
# 4                Placed               12.16
# ...                 ...                 ...
# 99995            Placed               14.54
# 99996        Not Placed                0.00
# 99997            Placed               13.45
# 99998        Not Placed                0.00
# 99999            Placed               14.43
#
# [100000 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'cgpa', 'branch', 'college_tier',
#        'internships_count', 'projects_count', 'certifications_count',
#        'coding_skill_score', 'aptitude_score', 'communication_skill_score',
#        'logical_reasoning_score', 'hackathons_participated', 'github_repos',
#        'linkedin_connections', 'mock_interview_score', 'attendance_percentage',
#        'backlogs', 'extracurricular_score', 'leadership_score',
#        'volunteer_experience', 'sleep_hours', 'study_hours_per_day',
#        'placement_status', 'salary_package_lpa'],
#       dtype='object')

# %%
df.drop(
    columns=[
        'coding_skill_score',
        'logical_reasoning_score',
        'mock_interview_score',
        'attendance_percentage'
    ],
    inplace=True
)

# %%
df
# Out:
#        student_id  age  gender  cgpa      branch college_tier  \
# 0               1   24    Male  7.53          IT       Tier 2
# 1               2   21    Male  7.92         CSE       Tier 2
# 2               3   22  Female  8.60         EEE       Tier 1
# 3               4   24    Male  6.68         CSE       Tier 1
# 4               5   20  Female  8.43          IT       Tier 3
# ...           ...  ...     ...   ...         ...          ...
# 99995       99996   21    Male  7.97  Mechanical       Tier 2
# 99996       99997   18  Female  7.79         CSE       Tier 1
# 99997       99998   20  Female  6.71          IT       Tier 2
# 99998       99999   19  Female  7.21         CSE       Tier 2
# 99999      100000   22  Female  8.58         ECE       Tier 3
#
#        internships_count  projects_count  certifications_count  \
# 0                      4               6                     1
# 1                      1               3                     6
# 2                      0               1                     1
# 3                      0               2                     2
# 4                      1               4                     3
# ...                  ...             ...                   ...
# 99995                  0               3                     5
# 99996                  1               1                     2
# 99997                  2               4                     4
# 99998                  2               3                     0
# 99999                  1               3                     2
#
#        aptitude_score  ...  github_repos  linkedin_connections  backlogs  \
# 0           81.707722  ...             1                   184         2
# 1           63.116715  ...             2                   539         1
# 2           48.658753  ...             2                   568         0
# 3           66.376653  ...             1                   550         1
# 4           61.274985  ...             4                   833         1
# ...               ...  ...           ...                   ...       ...
# 99995       56.904150  ...             5                   495         0
# 99996       55.729008  ...             2                   958         1
# 99997       48.725390  ...             6                   272         0
# 99998       79.336599  ...             6                   576         1
# 99999       89.261932  ...             1                   812         0
#
#        extracurricular_score  leadership_score  volunteer_experience  \
# 0                  63.382726         52.938240                   Yes
# 1                  73.694605         60.198856                    No
# 2                  63.329294         43.708803                    No
# 3                  47.636099         56.549154                   Yes
# 4                   0.000000         67.268893                    No
# ...                      ...               ...                   ...
# 99995              54.399022         66.446410                   Yes
# 99996              33.692154         69.025632                   Yes
# 99997              64.989215         32.733645                   Yes
# 99998              72.478779         32.205517                    No
# 99999              48.363818         21.166444                   Yes
#
#        sleep_hours study_hours_per_day  placement_status  salary_package_lpa
# 0              6.7                 3.6        Not Placed                0.00
# 1              4.4                 2.3        Not Placed                0.00
# 2              8.8                 5.9            Placed               11.99
# 3              8.1                 4.4        Not Placed                0.00
# 4              8.7                 3.4            Placed               12.16
# ...            ...                 ...               ...                 ...
# 99995          8.0                 4.3            Placed               14.54
# 99996          4.4                 3.1        Not Placed                0.00
# 99997          7.6                 2.9            Placed               13.45
# 99998          4.9                 2.8        Not Placed                0.00
# 99999          6.5                 2.9            Placed               14.43
#
# [100000 rows x 22 columns]

# %%
df.shape
# Out:
# (100000, 22)

# %%
df.isnull().sum()
# Out:
# student_id                   0
# age                          0
# gender                       0
# cgpa                         0
# branch                       0
# college_tier                 0
# internships_count            0
# projects_count               0
# certifications_count         0
# aptitude_score               0
# communication_skill_score    0
# hackathons_participated      0
# github_repos                 0
# linkedin_connections         0
# backlogs                     0
# extracurricular_score        0
# leadership_score             0
# volunteer_experience         0
# sleep_hours                  0
# study_hours_per_day          0
# placement_status             0
# salary_package_lpa           0
# dtype: int64

# %%
df.dtypes
# Out:
# student_id                     int64
# age                            int64
# gender                        object
# cgpa                         float64
# branch                        object
# college_tier                  object
# internships_count              int64
# projects_count                 int64
# certifications_count           int64
# aptitude_score               float64
# communication_skill_score    float64
# hackathons_participated        int64
# github_repos                   int64
# linkedin_connections           int64
# backlogs                       int64
# extracurricular_score        float64
# leadership_score             float64
# volunteer_experience          object
# sleep_hours                  float64
# study_hours_per_day          float64
# placement_status              object
# salary_package_lpa           float64
# dtype: object

# %%
df.to_csv("Student_Dataset.csv")
